# %%
import pickle
import torch

# %%
with open("2d.pkl", "rb") as f:
    two_d = pickle.load(f)

# %%
two_d
# Out:
# tensor([[[3.1198e-10, 2.2942e-10, 2.9214e-10,  ..., 2.5978e-10,
#           2.5795e-10, 2.0934e-10],
#          [5.9571e-10, 5.6111e-10, 5.3587e-10,  ..., 4.3400e-10,
#           5.5923e-10, 5.4353e-10],
#          [1.9830e-09, 2.4383e-09, 2.0508e-09,  ..., 1.9215e-09,
#           2.1862e-09, 1.5473e-09],
#          ...,
#          [6.9810e-15, 7.8019e-15, 7.9910e-15,  ..., 6.5034e-15,
#           7.7126e-15, 8.6304e-15],
#          [2.0335e-15, 1.8112e-15, 2.0257e-15,  ..., 2.1153e-15,
#           1.9970e-15, 1.9489e-15],
#          [1.0401e-15, 7.1739e-16, 9.0364e-16,  ..., 8.5741e-16,
#           1.0684e-15, 7.9986e-16]],
#
#         [[5.1003e-09, 3.8500e-09, 4.8309e-09,  ..., 4.3490e-09,
#           4.2986e-09, 3.5954e-09],
#          [9.4060e-09, 8.8863e-09, 8.5670e-09,  ..., 7.0910e-09,
#           8.9105e-09, 8.7984e-09],
#          [2.9955e-08, 3.6082e-08, 3.1081e-08,  ..., 2.9077e-08,
#           3.2942e-08, 2.4311e-08],
#          ...,
# ...

# %%
with open("3d_surface.pkl", "rb") as f:
    three_d = pickle.load(f)

# %%
three_d
# Out:
# tensor([[[2.4591e-10, 2.9939e-10, 2.5461e-10,  ..., 2.5532e-10,
#           2.7137e-10, 2.1425e-10],
#          [6.0491e-10, 5.4158e-10, 5.3651e-10,  ..., 5.4586e-10,
#           4.8295e-10, 5.2007e-10],
#          [1.8707e-09, 2.4709e-09, 1.9560e-09,  ..., 2.0585e-09,
#           2.1896e-09, 1.5709e-09],
#          ...,
#          [9.5037e-15, 7.9793e-15, 9.0190e-15,  ..., 7.5139e-15,
#           6.9583e-15, 7.4003e-15],
#          [2.1547e-15, 2.4927e-15, 2.0431e-15,  ..., 1.9530e-15,
#           1.5682e-15, 2.1566e-15],
#          [1.1960e-15, 1.0086e-15, 1.1575e-15,  ..., 9.2965e-16,
#           9.3331e-16, 8.7092e-16]],
#
#         [[4.1053e-09, 4.9139e-09, 4.2666e-09,  ..., 4.2648e-09,
#           4.5146e-09, 3.6699e-09],
#          [9.5573e-09, 8.5864e-09, 8.6079e-09,  ..., 8.7275e-09,
#           7.7698e-09, 8.4589e-09],
#          [2.8371e-08, 3.6576e-08, 2.9789e-08,  ..., 3.1159e-08,
#           3.2851e-08, 2.4757e-08],
#          ...,
# ...

# %%
two_d.shape
# Out:
# torch.Size([99, 50, 50])

# %%
three_d.shape
# Out:
# torch.Size([99, 50, 50])

# %%
torch.linalg.norm(two_d - three_d) / torch.linalg.norm(two_d)
# Out:
# tensor(0.0020, device='cuda:0', dtype=torch.float64)
